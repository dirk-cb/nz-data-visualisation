# %%
# Explorating the different API requests
from urllib3 import request
import os
import json
import pandas as pd
import io
from dotenv import load_dotenv
import json
from pathlib import Path
import numpy as np
_ = load_dotenv()

# %%
API_KEY = os.getenv("STATS_NZ_API_KEY_PRIMARY")

# %%
link =  "data/regions.json"

regions_json = json.loads(Path(link).read_text("utf-8"))

# %%
url = "https://api.data.stats.govt.nz/rest/data/STATSNZ,CEN23_ECI_019,1.0/2023.99+15+14+13+12+18+17+16+09+08+07+06+05+04+03+02+01..77.99.99?dimensionAtObservation=AllDimensions&format=csvfilewithlabels"

response = request(
    method="GET"
    , url = url
    , headers={
        "Ocp-Apim-Subscription-Key":API_KEY

    }
)

ethnicity_data = response.data.decode("utf-8")

df = pd.read_csv(io.StringIO(ethnicity_data))

# %%
transformed_df = df.copy()

COLS = {
    "Ethnicity":"ethnicity"
    , "Area": "region"
    #, "CEN23_GEO_002"
    , "OBS_VALUE": "count"
}

EXCLUDE = [
    "Not elsewhere included"
    , "Total stated - ethnicity"
]

RENAME = {
    "Middle Eastern/Latin American/African":"mena"
    , "Other ethnicity nec":"_other"
    , "Total - ethnicity":"total"
    , "Pacific Peoples": "pasifika"
    , "Asian": "asian"
    , "European": "nz_european"
    , "Māori": "māori"
}

transformed_df = transformed_df[COLS.keys()]\
    .rename(columns=COLS)\
    .query(f"ethnicity not in {EXCLUDE}")\
    .pivot(index="region", columns="ethnicity", values="count").reset_index()\
    .assign(other=lambda x: x["Other ethnicity nec"] + x["New Zealander"])\
    .rename(columns=RENAME)\
    .drop(columns=["_other", "New Zealander"])\
    

#transformed_df#.to_json(orient="records")
transformed_df
# Out:
# ethnicity                     region   asian  nz_european   mena   māori  \
# 0                Area Outside Region      18          459      6     420
# 1                    Auckland Region  518178       825144  44718  203544
# 2               Bay of Plenty Region   29262       240087   3954  102387
# 3                  Canterbury Region   86430       522498  10299   69060
# 4                    Gisborne Region    1968        28905    381   28029
# 5                 Hawke's Bay Region   11361       128415   1398   50076
# 6          Manawatū-Whanganui Region   19329       196431   2394   63177
# 7                 Marlborough Region    2667        42450    738    7344
# 8                      Nelson Region    4533        44544    714    6252
# 9                   Northland Region    9345       141594   1263   72612
# 10                      Otago Region   20379       205224   5211   23910
# 11                  Southland Region    7152        84195   1014   16848
# 12                   Taranaki Region    7215       105366    978   27411
# 13                     Tasman Region    2298        52416    435    5745
# 14                    Waikato Region   60792       357624   7146  125574
# 15                 Wellington Region   79314       378429  11934   80613
# 16                 West Coast Region    1335        29964    180    4491
#
# ethnicity  pasifika    total  other
# 0                24      633      9
# 1            275079  1656486  15174
# 2             14202   334140   3558
# 3             23868   651027   8220
# 4              2841    51135    465
# 5             10902   175074   2118
# 6             12522   251412   3339
# 7              1821    49431    744
# 8              1485    52584    705
# 9              9486   194007   2211
# 10             8274   240900   3210
# 11             3351   100143   1506
# 12             3234   126015   1719
# 13             1509    57807    915
# 14            26139   498771   5745
# 15            47349   520971   5826
# 16              540    33390    720

# %%
#[x["properties"]["name"] in transformed_df.region.unique() for x in regions_json["features"]]

for region in regions_json["features"]:
    region_name = region["properties"]["name"]
    print(region_name)
    region_ethnicity_data = transformed_df.query("region == @region_name")

    if len(region_ethnicity_data) == 1:

        ethnicity = region_ethnicity_data.to_dict(orient='records')[0]


        region["properties"]["ethnicity"]=ethnicity

with open("data/regions_with_ethnicity.json", "w", encoding="utf-8") as f:
    json.dump(regions_json, f)
# Out:
# Northland Region
# Auckland Region
# Waikato Region
# Bay of Plenty Region
# Gisborne Region
# Hawke's Bay Region
# Taranaki Region
# Manawatū-Whanganui Region
# Wellington Region
# West Coast Region
# Canterbury Region
# Otago Region
# Southland Region
# Tasman Region
# Nelson Region
# Marlborough Region
# Area Outside Region

# %%
sa3_json = json.loads(Path("data/sa3.json").read_text("utf-8"))

url = "https://api.data.stats.govt.nz/rest/data/STATSNZ,CEN23_POP_003,1.0/2023..777+69+61+5+4+3+2+1.99.99?dimensionAtObservation=AllDimensions&format=csvfilewithlabels"

response = request(
    method="GET"
    , url = url
    , headers={
        "Ocp-Apim-Subscription-Key":API_KEY

    }
)

ethnicity_data = response.data.decode("utf-8")

df = pd.read_csv(io.StringIO(ethnicity_data))

#print("+".join(all_codes[0:10]))

#lgbt= f"https://api.data.stats.govt.nz/rest/data/STATSNZ,CEN23_TBT_008,1.0/rb3+rbTS+rb2+rb1.{"+".join(all_codes[0:100])}.2023?dimensionAtObservation=AllDimensions&format=csvfilewithlabels"

lgbt="https://api.data.stats.govt.nz/rest/data/STATSNZ,CEN23_TBT_008,1.0/rb3+rbTS+rb2+rb1..2023?dimensionAtObservation=AllDimensions&format=csvfilewithlabels"

response = request(
    method="GET"
    , url = lgbt
    , headers={
        "Ocp-Apim-Subscription-Key":API_KEY
    }
)

lgbt_data = response.data.decode("utf-8")

lgbt_df = pd.read_csv(io.StringIO(lgbt_data))

# %%
transformed_df = df.copy()

all_codes = [x["properties"]["SA32025_V1_00"] for x in sa3_json["features"]]

COLS = {
    "Ethnicity":"ethnicity"
    , "Area": "region"
    #, "CEN23_GEO_002"
    , "CEN23_GEO_004": "region_code"
    , "OBS_VALUE": "count"
}

EXCLUDE = [
    "Not elsewhere included"
]

RENAME = {
    "Middle Eastern/Latin American/African":"mena"
    , "Other ethnicity nec":"_other"
    , "Total stated - ethnicity":"total"
    , "Pacific Peoples": "pasifika"
    , "Asian": "asian"
    , "European": "nz_european"
    , "Māori": "māori"
}



transformed_df = transformed_df[COLS.keys()]\
    .rename(columns=COLS)\
    .query(f"ethnicity not in {EXCLUDE}")\
    .pivot(index=["region", "region_code"], columns="ethnicity", values="count")\
    .reset_index()\
    .assign(other=lambda x: x["Other ethnicity nec"] + x["New Zealander"])\
    .rename(columns=RENAME)\
    .query("asian.notna()")\
    .drop(columns=["_other", "New Zealander"])\
    

#transformed_df#.to_json(orient="records")
#transformed_df.query("region == 'Kaikoura District'")
transformed_df#.Ethnicity.unique()
# Out:
# ethnicity                    region  region_code   asian  nz_european   mena  \
# 0                        Abbotsford        62140   144.0       2682.0    9.0
# 1                        Acacia Bay        53200    75.0       1629.0    9.0
# 2               Addington-Middleton        61110  1734.0       3612.0  183.0
# 3                           Ahuriri        54250    54.0        987.0   12.0
# 4                        Aidanfield        61180  1425.0       2367.0   39.0
# ..                              ...          ...     ...          ...    ...
# 993        Ōtorohanga District East        53060   396.0       5934.0   51.0
# 994        Ōtorohanga District West        53040    57.0       2013.0    6.0
# 995                         Ōtāhuhu        51830  4077.0       2916.0  243.0
# 996                          Ōwhata        53660   603.0       3915.0   54.0
# 997                      Ōwhiro Bay        56000   330.0       1497.0   60.0
#
# ethnicity   māori  pasifika    total  other
# 0           285.0      87.0   2916.0   27.0
# 1           216.0      18.0   1770.0   30.0
# 2           690.0     276.0   5898.0   63.0
# 3           180.0      30.0   1155.0   27.0
# 4           177.0      75.0   3870.0   42.0
# ..            ...       ...      ...    ...
# 993        2508.0     243.0   7827.0  105.0
# 994         876.0      87.0   2586.0   42.0
# 995        2472.0    7335.0  14778.0   54.0
# 996        3102.0     381.0   6468.0   72.0
# 997         267.0     159.0   1995.0   24.0
#
# [936 rows x 9 columns]

# %%
lgbt_df
# Out:
#       STRUCTURE                STRUCTURE_ID  \
# 0      DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 1      DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 2      DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 3      DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 4      DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# ...         ...                         ...
# 17687  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 17688  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 17689  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 17690  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 17691  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
#
#                                           STRUCTURE_NAME ACTION  \
# 0      Totals by topic for individuals, (RC, TALB, UR...      I
# 1      Totals by topic for individuals, (RC, TALB, UR...      I
# 2      Totals by topic for individuals, (RC, TALB, UR...      I
# 3      Totals by topic for individuals, (RC, TALB, UR...      I
# 4      Totals by topic for individuals, (RC, TALB, UR...      I
# ...                                                  ...    ...
# 17687  Totals by topic for individuals, (RC, TALB, UR...      I
# 17688  Totals by topic for individuals, (RC, TALB, UR...      I
# 17689  Totals by topic for individuals, (RC, TALB, UR...      I
# 17690  Totals by topic for individuals, (RC, TALB, UR...      I
# 17691  Totals by topic for individuals, (RC, TALB, UR...      I
#
#       CEN23_TBT_IND_003                            Variable codes  \
# 0                   rb1                                   LGBTIQ+
# 1                  rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 2                   rb2                               Not LGBTIQ+
# 3                   rb3             LGBTIQ+ status unidentifiable
# 4                   rb1                                   LGBTIQ+
# ...                 ...                                       ...
# 17687               rb3             LGBTIQ+ status unidentifiable
# 17688              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 17689              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 17690               rb2                               Not LGBTIQ+
# 17691              rbTS  Total stated - rainbow/LGBTIQ+ indicator
#
#       CEN23_TBT_GEO_006                         Area  CEN23_YEAR_001  \
# 0                182300                     Fencourt            2023
# 1                  2029  Inlets Marlborough District            2023
# 2                  2032                  Ngākuta Bay            2023
# 3                246700                 Eastern Bays            2023
# 4                323500                    Middleton            2023
# ...                 ...                          ...             ...
# 17687            151800             Massey Road West            2023
# 17688             61260                        Opawa            2023
# 17689               030            Hastings District            2023
# 17690              1082                 Snells Beach            2023
# 17691             55250           Inlet Porirua City            2023
#
#        Census year  OBS_VALUE  Observation Value OBS_STATUS Observation Status
# 0             2023        9.0                NaN        NaN                NaN
# 1             2023       21.0                NaN        NaN                NaN
# 2             2023       54.0                NaN        NaN                NaN
# 3             2023      102.0                NaN        NaN                NaN
# 4             2023       21.0                NaN        NaN                NaN
# ...            ...        ...                ...        ...                ...
# 17687         2023      627.0                NaN        NaN                NaN
# 17688         2023     1086.0                NaN        NaN                NaN
# 17689         2023    52680.0                NaN        NaN                NaN
# 17690         2023     2562.0                NaN        NaN                NaN
# 17691         2023        NaN                NaN          c       Confidential
#
# [17692 rows x 14 columns]

# %%
# LGBT

lgbt_transformed_df = lgbt_df

LGBT_COLS = {
    "Variable codes":"preference"
    , "Area": "region"
    #, "CEN23_GEO_002"
    , "CEN23_TBT_GEO_006": "region_code"
    , "OBS_VALUE": "count"
}

LGBT_EXCLUDE = [
    #"Not elsewhere included"
]

LGBT_RENAME = {
    "LGBTIQ+":"lgbt"
    , "Not LGBTIQ+":"non_lgbt"
    #, "Total stated - rainbow/LGBTIQ+ indicator":"total"
    , "Pacific Peoples": "pasifika"
    , "Asian": "asian"
    , "European": "nz_european"
    , "Māori": "māori"
}


lgbt_transformed_df = lgbt_transformed_df[LGBT_COLS.keys()]\
    .rename(columns=LGBT_COLS)\
    .query(f"preference not in {LGBT_EXCLUDE} and region_code in {all_codes}")\
    .pivot(index=["region", "region_code"], columns="preference", values="count")\
    .reset_index()\
    .rename(columns=LGBT_RENAME)\
    .assign(total=lambda x: (x["non_lgbt"] + x["lgbt"]))\
    .query("lgbt.notna()")\
    .drop(columns=["LGBTIQ+ status unidentifiable", "Total stated - rainbow/LGBTIQ+ indicator"])

lgbt_transformed_df
# Out:
# preference                    region region_code   lgbt  non_lgbt   total
# 0                         Abbotsford       62140   78.0    2103.0  2181.0
# 1                         Acacia Bay       53200   33.0    1287.0  1320.0
# 2                Addington-Middleton       61110  477.0    4116.0  4593.0
# 3                            Ahuriri       54250   24.0     831.0   855.0
# 4                         Aidanfield       61180  105.0    2865.0  2970.0
# ..                               ...         ...    ...       ...     ...
# 867         Ōtorohanga District East       53060  156.0    4830.0  4986.0
# 868         Ōtorohanga District West       53040   51.0    1575.0  1626.0
# 869                          Ōtāhuhu       51830  408.0    8550.0  8958.0
# 870                           Ōwhata       53660  153.0    3762.0  3915.0
# 871                       Ōwhiro Bay       56000  117.0    1428.0  1545.0
#
# [860 rows x 5 columns]

# %%
for region in sa3_json["features"]:
    region_name = region["properties"]["name"]
    region_code = int(region["properties"]["SA32025_V1_00"])
    region_code_2 = region["properties"]["SA32025_V1_00"]
    

    region_ethnicity_data = transformed_df.query("region == @region_name and region_code == @region_code")
    region_lgbt_data = lgbt_transformed_df.query("region == @region_name and region_code == @region_code_2")

    #print(len(region_ethnicity_data))
    if len(region_ethnicity_data) == 1:

        ethnicity = region_ethnicity_data.to_dict(orient='records')[0]

        region["properties"]["ethnicity"]=ethnicity
    else:
        region["properties"]["ethnicity"]=None

    if len(region_lgbt_data) == 1:

        lgbt = region_lgbt_data.to_dict(orient='records')[0]

        region["properties"]["lgbt"]=lgbt
    else:
        region["properties"]["lgbt"]=None

with open("data/sa3_with_ethnicity.json", "w", encoding="utf-8") as f:
    json.dump(sa3_json,f)

# %%
sa3_json["features"][0]["properties"]["ethnicity"]

#for x in sa3_json["features"]:
    #print(x["properties"]["ethnicity"])
    #if x["properties"]["ethnicity"]["asian"] == np.nan:
    #    print(x["properties"]["ethnicity"])
# Out:
# {'region': 'Onerahi',
#  'region_code': 50300,
#  'asian': 342.0,
#  'nz_european': 4731.0,
#  'mena': 54.0,
#  'māori': 2157.0,
#  'pasifika': 321.0,
#  'total': 6411.0,
#  'other': 93.0}

# %%
all_codes = [x["properties"]["SA32025_V1_00"] for x in sa3_json["features"]]

#print("+".join(all_codes[0:10]))

lgbt= f"https://api.data.stats.govt.nz/rest/data/STATSNZ,CEN23_TBT_008,1.0/rb3+rbTS+rb2+rb1.{"+".join(all_codes[0:10])}.2023?dimensionAtObservation=AllDimensions&format=csvfilewithlabels"

response = request(
    method="GET"
    , url = lgbt
    , headers={
        "Ocp-Apim-Subscription-Key":API_KEY

    }
)

lgbt_data = response.data.decode("utf-8")

lgbt_df = pd.read_csv(io.StringIO(lgbt_data))

# %%
lgbt_df
# Out:
#    STRUCTURE                STRUCTURE_ID  \
# 0   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 1   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 2   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 3   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 4   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 5   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 6   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 7   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 8   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 9   DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 10  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 11  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 12  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 13  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 14  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 15  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 16  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 17  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 18  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 19  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 20  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 21  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 22  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 23  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 24  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 25  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 26  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 27  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 28  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 29  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 30  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 31  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 32  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 33  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 34  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 35  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 36  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 37  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 38  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
# 39  DATAFLOW  STATSNZ:CEN23_TBT_008(1.0)
#
#                                        STRUCTURE_NAME ACTION  \
# 0   Totals by topic for individuals, (RC, TALB, UR...      I
# 1   Totals by topic for individuals, (RC, TALB, UR...      I
# 2   Totals by topic for individuals, (RC, TALB, UR...      I
# 3   Totals by topic for individuals, (RC, TALB, UR...      I
# 4   Totals by topic for individuals, (RC, TALB, UR...      I
# 5   Totals by topic for individuals, (RC, TALB, UR...      I
# 6   Totals by topic for individuals, (RC, TALB, UR...      I
# 7   Totals by topic for individuals, (RC, TALB, UR...      I
# 8   Totals by topic for individuals, (RC, TALB, UR...      I
# 9   Totals by topic for individuals, (RC, TALB, UR...      I
# 10  Totals by topic for individuals, (RC, TALB, UR...      I
# 11  Totals by topic for individuals, (RC, TALB, UR...      I
# 12  Totals by topic for individuals, (RC, TALB, UR...      I
# 13  Totals by topic for individuals, (RC, TALB, UR...      I
# 14  Totals by topic for individuals, (RC, TALB, UR...      I
# 15  Totals by topic for individuals, (RC, TALB, UR...      I
# 16  Totals by topic for individuals, (RC, TALB, UR...      I
# 17  Totals by topic for individuals, (RC, TALB, UR...      I
# 18  Totals by topic for individuals, (RC, TALB, UR...      I
# 19  Totals by topic for individuals, (RC, TALB, UR...      I
# 20  Totals by topic for individuals, (RC, TALB, UR...      I
# 21  Totals by topic for individuals, (RC, TALB, UR...      I
# 22  Totals by topic for individuals, (RC, TALB, UR...      I
# 23  Totals by topic for individuals, (RC, TALB, UR...      I
# 24  Totals by topic for individuals, (RC, TALB, UR...      I
# 25  Totals by topic for individuals, (RC, TALB, UR...      I
# 26  Totals by topic for individuals, (RC, TALB, UR...      I
# 27  Totals by topic for individuals, (RC, TALB, UR...      I
# 28  Totals by topic for individuals, (RC, TALB, UR...      I
# 29  Totals by topic for individuals, (RC, TALB, UR...      I
# 30  Totals by topic for individuals, (RC, TALB, UR...      I
# 31  Totals by topic for individuals, (RC, TALB, UR...      I
# 32  Totals by topic for individuals, (RC, TALB, UR...      I
# 33  Totals by topic for individuals, (RC, TALB, UR...      I
# 34  Totals by topic for individuals, (RC, TALB, UR...      I
# 35  Totals by topic for individuals, (RC, TALB, UR...      I
# 36  Totals by topic for individuals, (RC, TALB, UR...      I
# 37  Totals by topic for individuals, (RC, TALB, UR...      I
# 38  Totals by topic for individuals, (RC, TALB, UR...      I
# 39  Totals by topic for individuals, (RC, TALB, UR...      I
#
#    CEN23_TBT_IND_003                            Variable codes  \
# 0                rb3             LGBTIQ+ status unidentifiable
# 1                rb3             LGBTIQ+ status unidentifiable
# 2                rb3             LGBTIQ+ status unidentifiable
# 3                rb3             LGBTIQ+ status unidentifiable
# 4                rb1                                   LGBTIQ+
# 5                rb2                               Not LGBTIQ+
# 6                rb2                               Not LGBTIQ+
# 7               rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 8                rb3             LGBTIQ+ status unidentifiable
# 9                rb1                                   LGBTIQ+
# 10              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 11               rb2                               Not LGBTIQ+
# 12               rb2                               Not LGBTIQ+
# 13               rb1                                   LGBTIQ+
# 14              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 15               rb1                                   LGBTIQ+
# 16              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 17               rb2                               Not LGBTIQ+
# 18               rb1                                   LGBTIQ+
# 19              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 20               rb2                               Not LGBTIQ+
# 21              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 22               rb1                                   LGBTIQ+
# 23               rb2                               Not LGBTIQ+
# 24               rb3             LGBTIQ+ status unidentifiable
# 25               rb1                                   LGBTIQ+
# 26              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 27               rb1                                   LGBTIQ+
# 28               rb3             LGBTIQ+ status unidentifiable
# 29               rb3             LGBTIQ+ status unidentifiable
# 30               rb2                               Not LGBTIQ+
# 31               rb3             LGBTIQ+ status unidentifiable
# 32               rb1                                   LGBTIQ+
# 33              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 34               rb3             LGBTIQ+ status unidentifiable
# 35               rb1                                   LGBTIQ+
# 36              rbTS  Total stated - rainbow/LGBTIQ+ indicator
# 37               rb2                               Not LGBTIQ+
# 38               rb2                               Not LGBTIQ+
# 39              rbTS  Total stated - rainbow/LGBTIQ+ indicator
#
#     CEN23_TBT_GEO_006                    Area  CEN23_YEAR_001  Census year  \
# 0               50410             Rodney East            2023         2023
# 1               50300                 Onerahi            2023         2023
# 2               50330  Kaipara District North            2023         2023
# 3               50380         Barrier Islands            2023         2023
# 4               50390            Rodney North            2023         2023
# 5               50410             Rodney East            2023         2023
# 6               50380         Barrier Islands            2023         2023
# 7               50320                   Waipū            2023         2023
# 8               50320                   Waipū            2023         2023
# 9               50340  Kaipara District South            2023         2023
# 10              50340  Kaipara District South            2023         2023
# 11              50340  Kaipara District South            2023         2023
# 12              50320                   Waipū            2023         2023
# 13              50380         Barrier Islands            2023         2023
# 14              50410             Rodney East            2023         2023
# 15              50410             Rodney East            2023         2023
# 16              50390            Rodney North            2023         2023
# 17              50350               Mangawhai            2023         2023
# 18              50330  Kaipara District North            2023         2023
# 19              50300                 Onerahi            2023         2023
# 20              50330  Kaipara District North            2023         2023
# 21              50400         Inlets Auckland            2023         2023
# 22              50310               Bream Bay            2023         2023
# 23              50300                 Onerahi            2023         2023
# 24              50350               Mangawhai            2023         2023
# 25              50400         Inlets Auckland            2023         2023
# 26              50330  Kaipara District North            2023         2023
# 27              50320                   Waipū            2023         2023
# 28              50340  Kaipara District South            2023         2023
# 29              50390            Rodney North            2023         2023
# 30              50400         Inlets Auckland            2023         2023
# 31              50400         Inlets Auckland            2023         2023
# 32              50300                 Onerahi            2023         2023
# 33              50350               Mangawhai            2023         2023
# 34              50310               Bream Bay            2023         2023
# 35              50350               Mangawhai            2023         2023
# 36              50310               Bream Bay            2023         2023
# 37              50310               Bream Bay            2023         2023
# 38              50390            Rodney North            2023         2023
# 39              50380         Barrier Islands            2023         2023
#
#     OBS_VALUE  Observation Value  OBS_STATUS  Observation Status
# 0        1395                NaN         NaN                 NaN
# 1         891                NaN         NaN                 NaN
# 2        1563                NaN         NaN                 NaN
# 3         204                NaN         NaN                 NaN
# 4         213                NaN         NaN                 NaN
# 5        6105                NaN         NaN                 NaN
# 6         825                NaN         NaN                 NaN
# 7        2409                NaN         NaN                 NaN
# 8         405                NaN         NaN                 NaN
# 9         186                NaN         NaN                 NaN
# 10       5496                NaN         NaN                 NaN
# 11       5310                NaN         NaN                 NaN
# 12       2319                NaN         NaN                 NaN
# 13         45                NaN         NaN                 NaN
# 14       6330                NaN         NaN                 NaN
# 15        225                NaN         NaN                 NaN
# 16       6612                NaN         NaN                 NaN
# 17       4509                NaN         NaN                 NaN
# 18        252                NaN         NaN                 NaN
# 19       4248                NaN         NaN                 NaN
# 20       6897                NaN         NaN                 NaN
# 21         27                NaN         NaN                 NaN
# 22        165                NaN         NaN                 NaN
# 23       4056                NaN         NaN                 NaN
# 24       1008                NaN         NaN                 NaN
# 25          0                NaN         NaN                 NaN
# 26       7149                NaN         NaN                 NaN
# 27         90                NaN         NaN                 NaN
# 28       1290                NaN         NaN                 NaN
# 29       1284                NaN         NaN                 NaN
# 30         27                NaN         NaN                 NaN
# 31          3                NaN         NaN                 NaN
# 32        195                NaN         NaN                 NaN
# 33       4653                NaN         NaN                 NaN
# 34       1119                NaN         NaN                 NaN
# 35        138                NaN         NaN                 NaN
# 36       5532                NaN         NaN                 NaN
# 37       5367                NaN         NaN                 NaN
# 38       6402                NaN         NaN                 NaN
# 39        870                NaN         NaN                 NaN
